# %% [markdown]
# <a href="https://colab.research.google.com/github/Linaqb/Talento_Tech/blob/main/Laboratorio1_Talentotech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Practica 1 de TalentoTech Incluye importar un Dataset

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Data/ventas.xlsx'

# %%
import pandas as pd

# %%
df_ventas = pd.read_excel(path)

# %%
df_ventas.columns
# Out:
# Index(['Fecha', 'Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %%
df_ventas.tail()
# Out:
#     Fecha Region      Producto Vendedor  Ventas
# 13  45335  Oeste    Accesorios     Sara    5442
# 14  45336  Oeste  Dispositivos    Kevin   10711
# 15  45337  Oeste  Dispositivos     Sara    8780
# 16  45338  Oeste      Sistemas    Kevin   32855
# 17  45339  Oeste      Sistemas     Sara   23151

# %%
df_ventas.head()
# Out:
#    Fecha   Region      Producto Vendedor  Ventas
# 0  45322  Central    Accesorios    David    8287
# 1  45323  Central    Accesorios    Karen    6909
# 2  45324  Central  Dispositivos    David   11420
# 3  45325  Central  Dispositivos    Karen   12948
# 4  45326  Central      Sistemas    David   20098

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     18 non-null     int64
#  1   Region    18 non-null     object
#  2   Producto  18 non-null     object
#  3   Vendedor  18 non-null     object
#  4   Ventas    18 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 848.0+ bytes

# %%
df_ventas.describe()
# Out:
#               Fecha        Ventas
# count     18.000000     18.000000
# mean   45330.500000  13307.388889
# std        5.338539   8153.055776
# min    45322.000000   4744.000000
# 25%    45326.250000   8410.250000
# 50%    45330.500000  10529.500000
# 75%    45334.750000  13491.750000
# max    45339.000000  32855.000000

# %%
df_ventas_hoy = df_ventas

# %%
df_ventas
# Out:
#     Fecha   Region      Producto Vendedor  Ventas
# 0   45322  Central    Accesorios    David    8287
# 1   45323  Central    Accesorios    Karen    6909
# 2   45324  Central  Dispositivos    David   11420
# 3   45325  Central  Dispositivos    Karen   12948
# 4   45326  Central      Sistemas    David   20098
# 5   45327  Central      Sistemas    Karen   30633
# 6   45328     Este    Accesorios      Ana    9323
# 7   45329     Este    Accesorios    Lucas    7667
# 8   45330     Este  Dispositivos      Ana   10348
# 9   45331     Este  Dispositivos    Lucas    9312
# 10  45332     Este      Sistemas      Ana   13531
# 11  45333     Este      Sistemas    Lucas   13374
# 12  45334    Oeste    Accesorios    Kevin    4744
# 13  45335    Oeste    Accesorios     Sara    5442
# 14  45336    Oeste  Dispositivos    Kevin   10711
# 15  45337    Oeste  Dispositivos     Sara    8780
# 16  45338    Oeste      Sistemas    Kevin   32855
# 17  45339    Oeste      Sistemas     Sara   23151
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Fecha']
  ys = series['Ventas']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(4, 4), layout='constrained')
df_sorted = df_ventas.sort_values('Fecha', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Region')):
  _plot_series(series, series_name, i)
  fig.legend(title='Region', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Fecha')
_ = plt.ylabel('Ventas')

# %%
#Ejercio 4: Calcular el promedio de ventas por region
print("ejercicio 4:calcular el promeedio de ventas por region")
df_venta = df_ventas.groupby('Region')['Ventas'].mean
print(df_ventas)
# Out:
# ejercicio 4:calcular el promeedio de ventas por region
#     Fecha   Region      Producto Vendedor  Ventas
# 0   45322  Central    Accesorios    David    8287
# 1   45323  Central    Accesorios    Karen    6909
# 2   45324  Central  Dispositivos    David   11420
# 3   45325  Central  Dispositivos    Karen   12948
# 4   45326  Central      Sistemas    David   20098
# 5   45327  Central      Sistemas    Karen   30633
# 6   45328     Este    Accesorios      Ana    9323
# 7   45329     Este    Accesorios    Lucas    7667
# 8   45330     Este  Dispositivos      Ana   10348
# 9   45331     Este  Dispositivos    Lucas    9312
# 10  45332     Este      Sistemas      Ana   13531
# 11  45333     Este      Sistemas    Lucas   13374
# 12  45334    Oeste    Accesorios    Kevin    4744
# 13  45335    Oeste    Accesorios     Sara    5442
# 14  45336    Oeste  Dispositivos    Kevin   10711
# 15  45337    Oeste  Dispositivos     Sara    8780
# 16  45338    Oeste      Sistemas    Kevin   32855
# ...
